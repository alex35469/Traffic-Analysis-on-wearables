# %%
import sys
import build_datasets
import machine_learning
import feature_extraction
import numpy as np
import pandas as pd
import sklearn
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
import operator
from sklearn import metrics
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt

BLE_CLASSIC_TOGGLE='classic'

pad = build_datasets.pad

# ===============================
# Load or rebuild datasets

all_sources_files = build_datasets.find_sources()
if BLE_CLASSIC_TOGGLE == 'ble':
    all_sources_files = [s for s in all_sources_files if not "Samsung" in s and not "Fossil" in s]
else:
    all_sources_files = [s for s in all_sources_files if "Samsung" in s or "Fossil" in s]
build_datasets.rebuild_all_datasets(all_sources_files, force_rebuild=True)
# Out:
# Common columns: ['Communication', 'LAP', 'Transmitter', 'Originator', 'Item', 'Application', 'Time delta', 'Packet Type', 'Payload', 'Status', 'Receiver', 'Packet #', 'Time']
# Loading and cleaning dataset data/FossilExploristHR_NoApp_Idle_Classic_enc_1.csv
# Loading and cleaning dataset data/FossilExploristHR_NoApp_Idle_Classic_enc_2.csv
# Loading and cleaning dataset data/FossilExploristHR_NoApp_Idle_Classic_enc_3.csv
# Loading and cleaning dataset data/FossilExploristHR_NoApp_Idle_Classic_enc_4.csv
# Loading and cleaning dataset data/FossilExploristHR_NoApp_Idle_Classic_enc_5.csv
# Loading and cleaning dataset data/FossilExploristHR_NoApp_PhoneCallMissed_Classic_enc_1.csv
# Loading and cleaning dataset data/FossilExploristHR_NoApp_PhoneCallMissed_Classic_enc_2.csv
# Loading and cleaning dataset data/FossilExploristHR_NoApp_PhoneCallMissed_Classic_enc_3.csv
# Loading and cleaning dataset data/FossilExploristHR_NoApp_PhoneCallMissed_Classic_enc_4.csv
# Loading and cleaning dataset data/FossilExploristHR_NoApp_PhoneCallMissed_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_Endomondo_Run_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_Endomondo_Run_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_Endomondo_Run_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_Endomondo_Run_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_Endomondo_Run_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_Endomondo_Walk_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_Endomondo_Walk_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_Endomondo_Walk_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_Endomondo_Walk_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_Endomondo_Walk_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_FITIV_Run_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_FITIV_Run_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_FITIV_Run_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_FITIV_Run_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_FITIV_Run_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_FITIV_Walk_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_FITIV_Walk_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_FITIV_Walk_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_FITIV_Walk_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_FITIV_Walk_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_MapMyRun_Run_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_MapMyRun_Run_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_MapMyRun_Run_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_MapMyRun_Run_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_MapMyRun_Run_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_MapMyRun_Walk_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_MapMyRun_Walk_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_MapMyRun_Walk_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_MapMyRun_Walk_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_MapMyRun_Walk_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_MyFitnessPal_CaloriesAdd_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_MyFitnessPal_CaloriesAdd_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_MyFitnessPal_CaloriesAdd_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_MyFitnessPal_CaloriesAdd_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_MyFitnessPal_CaloriesAdd_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_MyFitnessPal_WaterAdd_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_MyFitnessPal_WaterAdd_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_MyFitnessPal_WaterAdd_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_MyFitnessPal_WaterAdd_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_MyFitnessPal_WaterAdd_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_Email_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_Email_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_Email_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_Email_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_Email_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_7.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_PhotoTransfer_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_PhotoTransfer_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_PhotoTransfer_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_PhotoTransfer_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_PhotoTransfer_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_SmsReceivedOnPhone_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_SmsReceivedOnPhone_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_SmsReceivedOnPhone_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_SmsReceivedOnPhone_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_SmsSentFromWatch_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_NoApp_SmsSentFromWatch_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_Pear_Run_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_Pear_Run_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_Pear_Run_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_Pear_Run_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_Pear_Run_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_Pear_Walk_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_Pear_Walk_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_Pear_Walk_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_Pear_Walk_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_Pear_Walk_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_6.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_Run_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_Run_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_Run_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_Run_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_Run_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_1.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_2.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_3.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_4.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_5.csv
# Loading and cleaning dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_6.csv
# Dataset data/FossilExploristHR_NoApp_Idle_Classic_enc_1.csv contains 144 packets
# Dataset data/FossilExploristHR_NoApp_Idle_Classic_enc_2.csv contains 152 packets
# Dataset data/FossilExploristHR_NoApp_Idle_Classic_enc_3.csv contains 143 packets
# Dataset data/FossilExploristHR_NoApp_Idle_Classic_enc_4.csv contains 130 packets
# Dataset data/FossilExploristHR_NoApp_Idle_Classic_enc_5.csv contains 135 packets
# Dataset data/FossilExploristHR_NoApp_PhoneCallMissed_Classic_enc_1.csv contains 2737 packets
# Dataset data/FossilExploristHR_NoApp_PhoneCallMissed_Classic_enc_2.csv contains 2311 packets
# Dataset data/FossilExploristHR_NoApp_PhoneCallMissed_Classic_enc_3.csv contains 2349 packets
# Dataset data/FossilExploristHR_NoApp_PhoneCallMissed_Classic_enc_4.csv contains 1242 packets
# Dataset data/FossilExploristHR_NoApp_PhoneCallMissed_Classic_enc_5.csv contains 2616 packets
# Dataset data/SamsungGWatch_Endomondo_Run_Classic_enc_1.csv contains 6550 packets
# Dataset data/SamsungGWatch_Endomondo_Run_Classic_enc_2.csv contains 7400 packets
# Dataset data/SamsungGWatch_Endomondo_Run_Classic_enc_3.csv contains 8833 packets
# Dataset data/SamsungGWatch_Endomondo_Run_Classic_enc_4.csv contains 9625 packets
# Dataset data/SamsungGWatch_Endomondo_Run_Classic_enc_5.csv contains 7458 packets
# Dataset data/SamsungGWatch_Endomondo_Walk_Classic_enc_1.csv contains 5865 packets
# Dataset data/SamsungGWatch_Endomondo_Walk_Classic_enc_2.csv contains 7614 packets
# Dataset data/SamsungGWatch_Endomondo_Walk_Classic_enc_3.csv contains 8082 packets
# Dataset data/SamsungGWatch_Endomondo_Walk_Classic_enc_4.csv contains 9836 packets
# Dataset data/SamsungGWatch_Endomondo_Walk_Classic_enc_5.csv contains 8344 packets
# Dataset data/SamsungGWatch_FITIV_Run_Classic_enc_1.csv contains 5416 packets
# Dataset data/SamsungGWatch_FITIV_Run_Classic_enc_2.csv contains 5905 packets
# Dataset data/SamsungGWatch_FITIV_Run_Classic_enc_3.csv contains 4100 packets
# Dataset data/SamsungGWatch_FITIV_Run_Classic_enc_4.csv contains 4998 packets
# Dataset data/SamsungGWatch_FITIV_Run_Classic_enc_5.csv contains 1154 packets
# Dataset data/SamsungGWatch_FITIV_Walk_Classic_enc_1.csv contains 988 packets
# Dataset data/SamsungGWatch_FITIV_Walk_Classic_enc_2.csv contains 5534 packets
# Dataset data/SamsungGWatch_FITIV_Walk_Classic_enc_3.csv contains 913 packets
# Dataset data/SamsungGWatch_FITIV_Walk_Classic_enc_4.csv contains 670 packets
# Dataset data/SamsungGWatch_FITIV_Walk_Classic_enc_5.csv contains 686 packets
# Dataset data/SamsungGWatch_MapMyRun_Run_Classic_enc_1.csv contains 7245 packets
# Dataset data/SamsungGWatch_MapMyRun_Run_Classic_enc_2.csv contains 7162 packets
# Dataset data/SamsungGWatch_MapMyRun_Run_Classic_enc_3.csv contains 5568 packets
# Dataset data/SamsungGWatch_MapMyRun_Run_Classic_enc_4.csv contains 10493 packets
# Dataset data/SamsungGWatch_MapMyRun_Run_Classic_enc_5.csv contains 7813 packets
# Dataset data/SamsungGWatch_MapMyRun_Walk_Classic_enc_1.csv contains 2503 packets
# Dataset data/SamsungGWatch_MapMyRun_Walk_Classic_enc_2.csv contains 3771 packets
# Dataset data/SamsungGWatch_MapMyRun_Walk_Classic_enc_3.csv contains 4085 packets
# Dataset data/SamsungGWatch_MapMyRun_Walk_Classic_enc_4.csv contains 3745 packets
# Dataset data/SamsungGWatch_MapMyRun_Walk_Classic_enc_5.csv contains 3679 packets
# Dataset data/SamsungGWatch_MyFitnessPal_CaloriesAdd_Classic_enc_1.csv contains 515 packets
# Dataset data/SamsungGWatch_MyFitnessPal_CaloriesAdd_Classic_enc_2.csv contains 613 packets
# Dataset data/SamsungGWatch_MyFitnessPal_CaloriesAdd_Classic_enc_3.csv contains 630 packets
# Dataset data/SamsungGWatch_MyFitnessPal_CaloriesAdd_Classic_enc_4.csv contains 643 packets
# Dataset data/SamsungGWatch_MyFitnessPal_CaloriesAdd_Classic_enc_5.csv contains 661 packets
# Dataset data/SamsungGWatch_MyFitnessPal_WaterAdd_Classic_enc_1.csv contains 455 packets
# Dataset data/SamsungGWatch_MyFitnessPal_WaterAdd_Classic_enc_2.csv contains 647 packets
# Dataset data/SamsungGWatch_MyFitnessPal_WaterAdd_Classic_enc_3.csv contains 670 packets
# Dataset data/SamsungGWatch_MyFitnessPal_WaterAdd_Classic_enc_4.csv contains 798 packets
# Dataset data/SamsungGWatch_MyFitnessPal_WaterAdd_Classic_enc_5.csv contains 671 packets
# Dataset data/SamsungGWatch_NoApp_Email_Classic_enc_1.csv contains 660 packets
# Dataset data/SamsungGWatch_NoApp_Email_Classic_enc_2.csv contains 892 packets
# Dataset data/SamsungGWatch_NoApp_Email_Classic_enc_3.csv contains 1034 packets
# Dataset data/SamsungGWatch_NoApp_Email_Classic_enc_4.csv contains 1572 packets
# Dataset data/SamsungGWatch_NoApp_Email_Classic_enc_5.csv contains 2112 packets
# Dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_1.csv contains 5370 packets
# Dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_2.csv contains 5730 packets
# Dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_3.csv contains 6943 packets
# Dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_4.csv contains 5432 packets
# Dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_5.csv contains 4474 packets
# Dataset data/SamsungGWatch_NoApp_PhoneCallMissed_Classic_enc_7.csv contains 708 packets
# Dataset data/SamsungGWatch_NoApp_PhotoTransfer_Classic_enc_1.csv contains 6038 packets
# Dataset data/SamsungGWatch_NoApp_PhotoTransfer_Classic_enc_2.csv contains 4563 packets
# Dataset data/SamsungGWatch_NoApp_PhotoTransfer_Classic_enc_3.csv contains 4075 packets
# Dataset data/SamsungGWatch_NoApp_PhotoTransfer_Classic_enc_4.csv contains 5244 packets
# Dataset data/SamsungGWatch_NoApp_PhotoTransfer_Classic_enc_5.csv contains 6688 packets
# Dataset data/SamsungGWatch_NoApp_SmsReceivedOnPhone_Classic_enc_1.csv contains 1973 packets
# Dataset data/SamsungGWatch_NoApp_SmsReceivedOnPhone_Classic_enc_2.csv contains 1408 packets
# Dataset data/SamsungGWatch_NoApp_SmsReceivedOnPhone_Classic_enc_3.csv contains 1386 packets
# Dataset data/SamsungGWatch_NoApp_SmsReceivedOnPhone_Classic_enc_5.csv contains 1865 packets
# Dataset data/SamsungGWatch_NoApp_SmsSentFromWatch_Classic_enc_3.csv contains 3031 packets
# Dataset data/SamsungGWatch_NoApp_SmsSentFromWatch_Classic_enc_4.csv contains 2094 packets
# Dataset data/SamsungGWatch_Pear_Run_Classic_enc_1.csv contains 5442 packets
# Dataset data/SamsungGWatch_Pear_Run_Classic_enc_2.csv contains 5867 packets
# Dataset data/SamsungGWatch_Pear_Run_Classic_enc_3.csv contains 5481 packets
# Dataset data/SamsungGWatch_Pear_Run_Classic_enc_4.csv contains 7032 packets
# Dataset data/SamsungGWatch_Pear_Run_Classic_enc_5.csv contains 5313 packets
# Dataset data/SamsungGWatch_Pear_Walk_Classic_enc_1.csv contains 5576 packets
# Dataset data/SamsungGWatch_Pear_Walk_Classic_enc_2.csv contains 7016 packets
# Dataset data/SamsungGWatch_Pear_Walk_Classic_enc_3.csv contains 7734 packets
# Dataset data/SamsungGWatch_Pear_Walk_Classic_enc_4.csv contains 6317 packets
# Dataset data/SamsungGWatch_Pear_Walk_Classic_enc_5.csv contains 9509 packets
# Dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_1.csv contains 1893 packets
# Dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_2.csv contains 1487 packets
# Dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_3.csv contains 1833 packets
# Dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_4.csv contains 1692 packets
# Dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_5.csv contains 1979 packets
# Dataset data/SamsungGWatch_SamsungHealth_HeartRateStressTest_Classic_enc_6.csv contains 387 packets
# Dataset data/SamsungGWatch_SamsungHealth_Run_Classic_enc_1.csv contains 809 packets
# Dataset data/SamsungGWatch_SamsungHealth_Run_Classic_enc_2.csv contains 1644 packets
# Dataset data/SamsungGWatch_SamsungHealth_Run_Classic_enc_3.csv contains 1190 packets
# Dataset data/SamsungGWatch_SamsungHealth_Run_Classic_enc_4.csv contains 743 packets
# Dataset data/SamsungGWatch_SamsungHealth_Run_Classic_enc_5.csv contains 778 packets
# Dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_1.csv contains 1195 packets
# Dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_2.csv contains 761 packets
# Dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_3.csv contains 957 packets
# Dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_4.csv contains 1456 packets
# Dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_5.csv contains 706 packets
# Dataset data/SamsungGWatch_SamsungHealth_Walk_Classic_enc_6.csv contains 955 packets

# %%
def cut_in_events(xy_features, timeout=4.5):
    """
    Returns [[(time, size)],] where each list is separated by at least timeout time, from a given [(time,size)]
    """
    events = []
    def trim_and_add_event(start, end):
        start_trim = start
        while ys[start_trim] == 0 :
            start_trim += 1
            if start_trim >= len(ys):
                return None
        end_trim = end
        while ys[end_trim] == 0 :
            end_trim -= 1

        if start_trim > end_trim:
            print("You broke the matrix", start, end, start_trim, end_trim, len(xs), len(ys))
            sys.exit(1)

        xs_copy = xs[start_trim:end_trim]
        ys_copy = ys[start_trim:end_trim]
        events.append(dict(xs=xs_copy, ys=ys_copy))
        

    xs = xy_features['xs']
    ys = xy_features['ys']

    feature_start = 0
    last_activity_index = -1  # not even one activity seen yet, never create an event in this case
    index = 0

    while index < len(xs):

        if last_activity_index != -1 and xs[index] - xs[last_activity_index] > timeout:
            trim_and_add_event(feature_start, index)

            feature_start = index
            last_activity_index = -1 # not even one activity seen yet

        if ys[index] > 0:
            last_activity_index = index
        index += 1

    # don't forget the last event
    if feature_start < len(xs)-1:
        trim_and_add_event(feature_start, len(xs)-1)

    events = [e for e in events if e is not None]
    return events

# %%
def show_cutting(source_file, timeout=10):
    xy_uncut = build_datasets.dataset_file_to_xy_features(source_file)
    xy_events = cut_in_events(xy_uncut, timeout=timeout)
    
    plt.plot(xy_uncut['xs'], xy_uncut['ys'], label='Uncut')
    for i in range(len(xy_events)):
        plt.plot(xy_events[i]['xs'], xy_events[i]['ys'], label=str(i))
    plt.xlabel('Time [s]')
    plt.ylabel('Packet size [B]')
    plt.title(source_file)
    plt.legend()
    plt.xlim(0,45)
    #plt.ylim(0.8,1.4)
    plt.show()

# %%
for s in all_sources_files:
    [device, app, action, ble, pl, repeat] = s.replace('data/', '').replace('.csv', '').split('_')
    if repeat == "1":
        print("=======================================", device, app, action)
    show_cutting(s, timeout=10)
# Out:
# ======================================= FossilExploristHR NoApp Idle
# ======================================= FossilExploristHR NoApp PhoneCallMissed
# ======================================= SamsungGWatch Endomondo Run
# ======================================= SamsungGWatch Endomondo Walk
# ======================================= SamsungGWatch FITIV Run
# ======================================= SamsungGWatch FITIV Walk
# ======================================= SamsungGWatch MapMyRun Run
# ======================================= SamsungGWatch MapMyRun Walk
# ======================================= SamsungGWatch MyFitnessPal CaloriesAdd
# ======================================= SamsungGWatch MyFitnessPal WaterAdd
# ======================================= SamsungGWatch NoApp Email
# ======================================= SamsungGWatch NoApp PhoneCallMissed
# ======================================= SamsungGWatch NoApp PhotoTransfer
# ======================================= SamsungGWatch NoApp SmsReceivedOnPhone
# ======================================= SamsungGWatch Pear Run
# ======================================= SamsungGWatch Pear Walk
# ======================================= SamsungGWatch SamsungHealth HeartRateStressTest
# ======================================= SamsungGWatch SamsungHealth Run
# ======================================= SamsungGWatch SamsungHealth Walk
